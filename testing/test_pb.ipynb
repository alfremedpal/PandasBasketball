# %%
from PandasBasketball import pandasbasketball as pb
import pandas as pd
from bs4 import BeautifulSoup as soup
import seaborn as sns

# %%
df = pb.get_player("jamesle01", "playoffs_advanced")
df.head()
# Out:
#     Season Age   Tm   Lg Pos   G   MP   PER   TS%  3PAr  ...  TOV%  USG%  OWS  \
# 0  2005-06  21  CLE  NBA  SF  13  604  23.2  .557  .205  ...  15.3  33.5  1.0
# 1  2006-07  22  CLE  NBA  SF  20  893  23.9  .516  .188  ...  12.0  29.7  2.1
# 2  2007-08  23  CLE  NBA  SF  13  552  24.3  .525  .255  ...  13.4  34.7  1.0
# 3  2008-09  24  CLE  NBA  SF  14  580  37.4  .618  .260  ...   8.7  36.4  3.7
# 4  2009-10  25  CLE  NBA  SF  11  460  28.6  .607  .237  ...  13.7  30.9  1.5
#
#    DWS   WS WS/48  OBPM DBPM   BPM VORP
# 0  0.7  1.7  .135   5.3  2.0   7.3  1.4
# 1  1.6  3.7  .200   5.4  3.1   8.5  2.4
# 2  1.2  2.2  .187   6.6  4.7  11.3  1.9
# 3  1.1  4.8  .399  14.4  3.8  18.2  2.9
# 4  0.8  2.3  .242   7.9  3.4  11.2  1.5
#
# [5 rows x 27 columns]

# %%
for column_name in df.columns:
    if column_name not in ['Season', 'PER']:
        df = df.drop([column_name], axis=1)
        
df['avg_per'] = [15.0 for i in range(13)]
df['PER'] = df['PER'].astype(float)
df['Season'] = [int(season[-2:]) for season in df['Season']]

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 3 columns):
# Season     13 non-null int64
# PER        13 non-null float64
# avg_per    13 non-null float64
# dtypes: float64(2), int64(1)
# memory usage: 440.0 bytes

# %%
fig, ax = sns.lineplot(x=df['Season'], y=df['PER'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-f80c9fc44959> in <module>
# ----> 1 fig, ax = sns.lineplot(x=df['Season'], y=df['PER'])
#
# TypeError: 'AxesSubplot' object is not iterable
